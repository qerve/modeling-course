# %% [markdown]
# # Моделирование нелинейных систем. ДЗ-2 Вынужденные колебания маятника.
#
# Выполнил: Давыдов Владислав Олегович
#
# Преподаватель: Соловьев Виктор Роальдович
#
# 8 семестр, кафедра нанометрологии и наноматериалов

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp

# %% [markdown]
# ## $$ \ddot{\theta} + 2 \gamma \dot{\theta} + \omega_0^2 \theta = f_0 \cos{\omega t} $$

# %% [markdown]
# Положим $\omega_0 = 1, \; \gamma = (0.01, 0.1, 0.3)$
#
# Добавляем метод Верле из предыдущего задания:

# %%
def f_acceleration(q, dot_q, gamma, step_time):
    ddot_q=-np.sin(q)-2*dot_q*gamma+np.cos(step_time)
    return ddot_q

# %%
a3 = [1]
w3 = [0]
z = 0.13
fig, ax = plt.subplots()

def Verlet(time, shagov, q_0, dot_q_0, z):
    q = q_0
    dot_q = dot_q_0
    h = time/shagov
    step_time = h
    
    #  Euler first step
    ddot_q = f_acceleration(q, dot_q, z, step_time)
    
    b = q
    q1 = q + h*dot_q + h**2/2 * ddot_q
    dot_q1 = (q1-b)/h
    a3.append(q1)
    w3.append(dot_q1)
    ax.plot(q1, dot_q1, '*', c='tab:red')
    
    
    '''
    q1 = q + h*dot_q + h**2/2 * ddot_q #0.79
    dot_q1 = dot_q + h * ddot_q #-0.42
    '''
    
    '''
    w3.append(dot_q1)
    b = q
    q1 = q + h*dot_q + h**2/2 * ddot_q
    dot_q1 = (q-b)/h
    a3.append(q1)
    ax.plot(a3, w3, '.', c='tab:blue')
    '''

    for i in range(shagov):
        step_time = step_time + h
        ddot_q1 = f_acceleration(q1, dot_q1, 0.13, step_time)
        b = q1
        q2 = 2*q1 - q + ddot_q1 * h**2/2
        q = q1
        q1 = q2
        dot_q1 = (q1 - b)/h
        a3.append(q1)
        w3.append(dot_q1)
        ax.plot(q1, dot_q1, '.', c='tab:blue')
        
    return q, dot_q, ddot_q


Verlet(300, 2000, 1, 0, z)
ax.axhline(w3[0], c='tab:red', label='Start point')
ax.axvline(a3[0], c ='tab:red')
ax.set_xlabel('$q, \; grad$')
ax.set_ylabel('$\dfrac{dq}{dt} , \; grad/s$')
ax.set_title('$\gamma = 0.13$')
ax.plot(a3, w3, '-', label='Verlet method for forced oscillations')
ax.legend()

# %%
a3 = [1]
w3 = [0]
z = 0.01
fig, ax = plt.subplots()

def Verlet(time, shagov, q_0, dot_q_0, z):
    q = q_0
    dot_q = dot_q_0
    h = time/shagov
    step_time = h
    
    #  Euler first step
    ddot_q = f_acceleration(q, dot_q, z, step_time)
    
    b = q
    q1 = q + h*dot_q + h**2/2 * ddot_q
    dot_q1 = (q1-b)/h
    a3.append(q1)
    w3.append(dot_q1)
    ax.plot(q1, dot_q1, '*', c='tab:red')
    
    
    '''
    q1 = q + h*dot_q + h**2/2 * ddot_q #0.79
    dot_q1 = dot_q + h * ddot_q #-0.42
    '''
    
    '''
    w3.append(dot_q1)
    b = q
    q1 = q + h*dot_q + h**2/2 * ddot_q
    dot_q1 = (q-b)/h
    a3.append(q1)
    ax.plot(a3, w3, '.', c='tab:blue')
    '''

    for i in range(shagov):
        step_time = step_time + h
        ddot_q1 = f_acceleration(q1, dot_q1, z, step_time)
        b = q1
        q2 = 2*q1 - q + ddot_q1 * h**2/2
        q = q1
        q1 = q2
        dot_q1 = (q1 - b)/h
        a3.append(q1)
        w3.append(dot_q1)
        ax.plot(q1, dot_q1, '.', c='tab:blue')
        
    return q, dot_q, ddot_q


Verlet(300, 2000, 1, 0, z)
ax.axhline(w3[0], c='tab:red', label='Start point')
ax.axvline(a3[0], c ='tab:red')
ax.set_xlabel('$q, \; grad$')
ax.set_ylabel('$\dfrac{dq}{dt} , \; grad/s$')
ax.set_title('$\gamma = 0.01$')
ax.plot(a3, w3, '-', label='Verlet method for forced oscillations')
ax.legend()

# %%
a3 = [1]
w3 = [0]
z = 0.1
fig, ax = plt.subplots()

def Verlet(time, shagov, q_0, dot_q_0, z):
    q = q_0
    dot_q = dot_q_0
    h = time/shagov
    step_time = h
    
    #  Euler first step
    ddot_q = f_acceleration(q, dot_q, z, step_time)
    
    b = q
    q1 = q + h*dot_q + h**2/2 * ddot_q
    dot_q1 = (q1-b)/h
    a3.append(q1)
    w3.append(dot_q1)
    ax.plot(q1, dot_q1, '*', c='tab:red')
    
    
    '''
    q1 = q + h*dot_q + h**2/2 * ddot_q #0.79
    dot_q1 = dot_q + h * ddot_q #-0.42
    '''
    
    '''
    w3.append(dot_q1)
    b = q
    q1 = q + h*dot_q + h**2/2 * ddot_q
    dot_q1 = (q-b)/h
    a3.append(q1)
    ax.plot(a3, w3, '.', c='tab:blue')
    '''

    for i in range(shagov):
        step_time = step_time + h
        ddot_q1 = f_acceleration(q1, dot_q1, z, step_time)
        b = q1
        q2 = 2*q1 - q + ddot_q1 * h**2/2
        q = q1
        q1 = q2
        dot_q1 = (q1 - b)/h
        a3.append(q1)
        w3.append(dot_q1)
        ax.plot(q1, dot_q1, '.', c='tab:blue')
        
    return q, dot_q, ddot_q


Verlet(300, 2000, 1, 0, z)
ax.axhline(w3[0], c='tab:red', label='Start point')
ax.axvline(a3[0], c ='tab:red')
ax.set_xlabel('$q, \; grad$')
ax.set_ylabel('$\dfrac{dq}{dt} , \; grad/s$')
ax.set_title('$\gamma = 0.1$')
ax.plot(a3, w3, '-', label='Verlet method for forced oscillations')
ax.legend()

# %%
a3 = [1]
w3 = [0]
z = 0.3
fig, ax = plt.subplots()

def Verlet(time, shagov, q_0, dot_q_0, z):
    q = q_0
    dot_q = dot_q_0
    h = time/shagov
    step_time = h
    
    #  Euler first step
    ddot_q = f_acceleration(q, dot_q, z, step_time)
    
    b = q
    q1 = q + h*dot_q + h**2/2 * ddot_q
    dot_q1 = (q1-b)/h
    a3.append(q1)
    w3.append(dot_q1)
    ax.plot(q1, dot_q1, '*', c='tab:red')
    
    
    '''
    q1 = q + h*dot_q + h**2/2 * ddot_q #0.79
    dot_q1 = dot_q + h * ddot_q #-0.42
    '''
    
    '''
    w3.append(dot_q1)
    b = q
    q1 = q + h*dot_q + h**2/2 * ddot_q
    dot_q1 = (q-b)/h
    a3.append(q1)
    ax.plot(a3, w3, '.', c='tab:blue')
    '''

    for i in range(shagov):
        step_time = step_time + h
        ddot_q1 = f_acceleration(q1, dot_q1, z, step_time)
        b = q1
        q2 = 2*q1 - q + ddot_q1 * h**2/2
        q = q1
        q1 = q2
        dot_q1 = (q1 - b)/h
        a3.append(q1)
        w3.append(dot_q1)
        ax.plot(q1, dot_q1, '.', c='tab:blue')
        
    return q, dot_q, ddot_q


Verlet(300, 2000, 1, 0, z)
ax.axhline(w3[0], c='tab:red', label='Start point')
ax.axvline(a3[0], c ='tab:red')
ax.set_xlabel('$q, \; grad$')
ax.set_ylabel('$\dfrac{dq}{dt} , \; grad/s$')
ax.set_title('$\gamma = 0.3$')
ax.plot(a3, w3, '-', label='Verlet method for forced oscillations')
ax.legend()

# %% [markdown]
# ### Линеризуем маятник $\sin(\theta) \; --> \; \theta $

# %%
def l_acceleration(q, dot_q, gamma, step_time, p, wi):
    ddot_q=-q*wi-2*dot_q*gamma+np.cos(p*step_time)
    return ddot_q

# %%
a3 = [1]
w3 = [0]
z = 0.01
p = 1
wi = 1
fig, ax = plt.subplots()

def Verlet(time, shagov, q_0, dot_q_0, z):
    q = q_0
    dot_q = dot_q_0
    h = time/shagov
    step_time = h
    
    #  Euler first step
    ddot_q = l_acceleration(q, dot_q, z, step_time, p, wi)
    
    b = q
    q1 = q + h*dot_q + h**2/2 * ddot_q
    dot_q1 = (q1-b)/h
    a3.append(q1)
    w3.append(dot_q1)
    ax.plot(q1, dot_q1, '*', c='tab:red')
    
    
    '''
    q1 = q + h*dot_q + h**2/2 * ddot_q #0.79
    dot_q1 = dot_q + h * ddot_q #-0.42
    '''
    
    '''
    w3.append(dot_q1)
    b = q
    q1 = q + h*dot_q + h**2/2 * ddot_q
    dot_q1 = (q-b)/h
    a3.append(q1)
    ax.plot(a3, w3, '.', c='tab:blue')
    '''

    for i in range(shagov):
        step_time = step_time + h
        ddot_q1 = l_acceleration(q1, dot_q1, z, step_time, p, wi)
        b = q1
        q2 = 2*q1 - q + ddot_q1 * h**2/2
        q = q1
        q1 = q2
        dot_q1 = (q1 - b)/h
        a3.append(q1)
        w3.append(dot_q1)
        ax.plot(q1, dot_q1, '.', c='tab:blue')
        
    return q, dot_q, ddot_q


Verlet(300, 2000, 1, 0, z)
ax.axhline(w3[0], c='tab:red', label='Start point')
ax.axvline(a3[0], c ='tab:red')
ax.set_xlabel('$q, \; grad$')
ax.set_ylabel('$\dfrac{dq}{dt} , \; grad/s$')
ax.set_title('$\gamma = 0.01$, linear oscillations')
ax.plot(a3, w3, '-', label='Verlet method for forced oscillations')
ax.legend()

# %% [markdown]
# ### Собственная частота колебаний маятника:
# ## $$ \omega_c = \sqrt{\omega_0^2 - \gamma^2} $$

# %%
a3 = [1]
w3 = [0]
z = 0.1
p = 1
fig, ax = plt.subplots()

def Verlet(time, shagov, q_0, dot_q_0, z):
    q = q_0
    dot_q = dot_q_0
    h = time/shagov
    step_time = h
    
    #  Euler first step
    ddot_q = l_acceleration(q, dot_q, z, step_time, p, wi)
    
    b = q
    q1 = q + h*dot_q + h**2/2 * ddot_q
    dot_q1 = (q1-b)/h
    a3.append(q1)
    w3.append(dot_q1)
    ax.plot(q1, dot_q1, '*', c='tab:red')
    
    
    '''
    q1 = q + h*dot_q + h**2/2 * ddot_q #0.79
    dot_q1 = dot_q + h * ddot_q #-0.42
    '''
    
    '''
    w3.append(dot_q1)
    b = q
    q1 = q + h*dot_q + h**2/2 * ddot_q
    dot_q1 = (q-b)/h
    a3.append(q1)
    ax.plot(a3, w3, '.', c='tab:blue')
    '''

    for i in range(shagov):
        step_time = step_time + h
        ddot_q1 = l_acceleration(q1, dot_q1, z, step_time, p, wi)
        b = q1
        q2 = 2*q1 - q + ddot_q1 * h**2/2
        q = q1
        q1 = q2
        dot_q1 = (q1 - b)/h
        a3.append(q1)
        w3.append(dot_q1)
        ax.plot(q1, dot_q1, '.', c='tab:blue')
        
    return q, dot_q, ddot_q


Verlet(300, 2000, 1, 0, z)
tff = np.linspace(0, 300, 2000+2)
#ax.axhline(w3[0], c='tab:red', label='Start point')
#ax.axvline(a3[0], c ='tab:red')
ax.set_xlabel('$t, \; sec$')
ax.set_ylabel('$q , \; grad$')
ax.set_title('$\gamma = 0.01$, linear oscillations')
ax.plot(tff, a3, '-', label='Verlet method for forced oscillations')
ax.legend()

# %%
chastots = np.linspace(0.5, 2, 4)
